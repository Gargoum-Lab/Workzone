# %%
# !pip install pandas
# !pip install scikit-learn
# !pip install pyproj

# %%
import numpy as np
import pandas as pd
import glob
import os
import pyproj
from sklearn.neighbors import NearestNeighbors

# %%
input_root_path = "P:\SALMALIS Lab\Work Zone Dataset"
weather_path = "E:\OneDrive - UBC\Work Zone\data\WeatherInfo"
output_root_path = "../"

# %%
def load_csv_to_df(files, filename=None, is_excel=False):
    if is_excel:
        df = pd.concat((pd.read_excel(f) for f in files), ignore_index=True)
    else:
        df = pd.concat((pd.read_csv(f, skipinitialspace = True) for f in files), ignore_index=True)

    if filename:
        df.to_csv(os.path.join(output_root_path, filename), header = True, index=True)
    return df

# %%
travel_t = pd.read_csv(os.path.join(input_root_path, 'TravelTime_HaveCellCoverage.csv'))
del travel_t[travel_t.columns[0]]
travel_t
# Out:
# C:\Users\yegmo\AppData\Local\Temp\ipykernel_18920\413896161.py:1: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   travel_t = pd.read_csv(os.path.join(input_root_path, 'TravelTime_HaveCellCoverage.csv'))
#          AssetNumber                                 AssetIdentifier  \
# 0        49831911074                                       Spread 3B
# 1        49831911074                                       Spread 3B
# 2        49831911074                                       Spread 3B
# 3        49831911074                                       Spread 3B
# 4        49831911074                                       Spread 3B
# ...              ...                                             ...
# 1704313  86704972236  AP 6-A-66-A • NB • Macro Spiecapag JV • 1073.6
# 1704314  86704972236  AP 6-A-66-A • NB • Macro Spiecapag JV • 1073.6
# 1704315  86704972236  AP 6-A-66-A • NB • Macro Spiecapag JV • 1073.6
# 1704316  86704972236  AP 6-A-66-A • NB • Macro Spiecapag JV • 1073.6
# 1704317  86704972236  AP 6-A-66-A • NB • Macro Spiecapag JV • 1073.6
#
#                  CreatedDate  UnderConstructionTime  BaselineTime  DelayTime  \
# 0        2022-05-03 17:59:55                   2.20          2.13       0.07
# 1        2022-05-03 17:57:32                   2.20          2.13       0.07
# 2        2022-05-03 17:55:23                   2.20          2.13       0.07
# 3        2022-05-03 17:53:29                   2.20          2.13       0.07
# 4        2022-05-03 17:51:45                   2.23          2.13       0.10
# ...                      ...                    ...           ...        ...
# 1704313  2021-05-01 18:40:12                   1.38          1.48       0.00
# 1704314  2021-05-01 18:45:11                   1.38          1.48       0.00
# 1704315  2021-05-01 18:50:10                   1.38          1.48       0.00
# 1704316  2021-05-01 18:51:07                   1.37          1.48       0.00
# 1704317  2021-05-01 18:55:09                   1.37          1.48       0.00
#
#         State  SegmentLength TravelDirect     Spread  ... Weather:Lat  \
# 0          OK           3.36           SB  Spread 3B  ...       52.72
# 1          OK           3.36           SB  Spread 3B  ...       52.72
# 2          OK           3.36           SB  Spread 3B  ...       52.72
# 3          OK           3.36           SB  Spread 3B  ...       52.72
# 4          OK           3.36           SB  Spread 3B  ...       52.72
# ...       ...            ...          ...        ...  ...         ...
# 1704313    OK           2.45           NB  Spread 5B  ...       49.24
# 1704314    OK           2.45           NB  Spread 5B  ...       49.24
# 1704315    OK           2.45           NB  Spread 5B  ...       49.24
# 1704316    OK           2.45           NB  Spread 5B  ...       49.24
# 1704317    OK           2.45           NB  Spread 5B  ...       49.24
#
#         Weather:Temp Weather:Precip Weather:WindSpd  Traffic:SiteNo  \
# 0                NaN            NaN             NaN        23-010NS
# 1                NaN            NaN             NaN        23-010NS
# 2                NaN            NaN             NaN        23-010NS
# 3                NaN            NaN             NaN        23-010NS
# 4                NaN            NaN             NaN        23-010NS
# ...              ...            ...             ...             ...
# 1704313         14.2            0.0             6.0         17-015W
# 1704314         14.2            0.0             6.0         17-015W
# 1704315         14.2            0.0             6.0         17-015W
# 1704316         14.2            0.0             6.0         17-015W
# 1704317         14.2            0.0             6.0         17-015W
#
#          Traffic:IsTemporary  Traffic:AADT  Traffic:BaseYear  \
# 0                       True    355.333333            2017.0
# 1                       True    355.333333            2017.0
# 2                       True    355.333333            2017.0
# 3                       True    355.333333            2017.0
# 4                       True    355.333333            2017.0
# ...                      ...           ...               ...
# 1704313                 True    617.333333            2013.0
# 1704314                 True    617.333333            2013.0
# 1704315                 True    617.333333            2013.0
# 1704316                 True    617.333333            2013.0
# 1704317                 True    617.333333            2013.0
#
#          Traffic:CalculatedAADT  MaxSpeed
# 0                        373.10     100.0
# 1                        373.10     100.0
# 2                        373.10     100.0
# 3                        373.10     100.0
# 4                        373.10     100.0
# ...                         ...       ...
# 1704313                  666.72       NaN
# 1704314                  666.72       NaN
# 1704315                  666.72       NaN
# 1704316                  666.72       NaN
# 1704317                  666.72       NaN
#
# [1704318 rows x 34 columns]

# %%
travel_t.nunique()
# Out:
# AssetNumber                   274
# AssetIdentifier               132
# CreatedDate                495632
# UnderConstructionTime         576
# BaselineTime                  275
# DelayTime                     635
# State                           2
# SegmentLength                 133
# TravelDirect                    2
# Spread                          7
# TrafficImpact                   3
# RoadType                        3
# TrafficControlSetup             2
# CreatedDate:Date              171
# CreatedDate:Weekday             7
# CreatedDate:DayOfYear         107
# CreatedDate:Year                2
# CreatedDate:Month               4
# CreatedDate:Day                31
# CreatedDate:Hour               24
# CreatedDate:MinuteInDay      1440
# CreatedDate:Season              2
# Weather:StationID              12
# Weather:Long                   11
# Weather:Lat                    12
# Weather:Temp                  344
# Weather:Precip                 46
# Weather:WindSpd                39
# Traffic:SiteNo                 16
# Traffic:IsTemporary             2
# Traffic:AADT                  255
# Traffic:BaseYear                5
# Traffic:CalculatedAADT        384
# MaxSpeed                        6
# dtype: int64

# %%
assets = pd.read_csv(os.path.join(input_root_path, 'Recommended_Assets_Merged.csv'))
del assets[assets.columns[0]]
assets = assets.dropna(subset=['Segment Name'])
print(f'NaN:\n{assets.isna().sum()}')
assets
# Out:
# NaN:
# Asset Number                0
# Segment Name                0
# Segment Length              1
# Baseline                    2
# Direct of Travel            0
# Spread                      0
# Traffic Impact              2
# Road Type                   0
# Traffic Control Setup       0
# Easting                    22
# Northing                   22
# Most Recent Activation    131
# Cell Coverage             449
# UTM Zone                  118
# dtype: int64
#      Asset Number   Segment Name  Segment Length  Baseline Direct of Travel  \
# 0     62134790681  AP 3-B-12-A-1           2.746      1.72               NB
# 1     10897197432  AP 3-B-12-A-1           2.746      1.73               SB
# 2     12768050215  AP 3-B-13-A-1           2.970      1.92               NB
# 3     56678162306  AP 3-B-13-A-1           2.970      1.92               SB
# 4     86851077697  AP 3-B-13-A-3          18.000       NaN               NB
# ..            ...            ...             ...       ...              ...
# 619   34684428742        T3920.0           4.840      0.00               SB
# 620   69027783597        T4068.3           3.460      0.00               SB
# 621   92801985490        T4068.3           3.480      0.00               NB
# 622   16764775025     TWS_460042           3.690      2.58               SB
# 623   86449733135     TWS_460042           3.690      2.60               NB
#
#            Spread Traffic Impact                      Road Type  \
# 0       Spread 3B           High  Multi-Lane Undivided Roadways
# 1       Spread 3B           High  Multi-Lane Undivided Roadways
# 2       Spread 3B           High  Multi-Lane Undivided Roadways
# 3       Spread 3B           High  Multi-Lane Undivided Roadways
# 4       Spread 3B           High  Multi-Lane Undivided Roadways
# ..            ...            ...                            ...
# 619     Spread 5A           High             Multi-Lane Divided
# 620     Spread 5B           High             Multi-Lane Divided
# 621     Spread 5B           High             Multi-Lane Divided
# 622  Reactivation           High  Multi-Lane Undivided Roadways
# 623  Reactivation           High  Multi-Lane Undivided Roadways
#
#     Traffic Control Setup       Easting      Northing Most Recent Activation  \
# 0                    SLAT  344630.96633  5.861839e+06              2/25/2022
# 1                    SLAT  344630.96633  5.861839e+06              2/25/2022
# 2                    SLAT  344922.86601  5.860906e+06               4/2/2022
# 3                    SLAT  344922.86601  5.860906e+06               4/2/2022
# 4                    SLAT  346092.86128  5.857159e+06                    NaN
# ..                    ...           ...           ...                    ...
# 619          Lane Closure  660846.97920  5.552540e+06                    NaN
# 620          Lane Closure           NaN           NaN                    NaN
# 621          Lane Closure           NaN           NaN                    NaN
# 622          Lane Closure  356159.86762  5.876918e+06               4/4/2022
# 623          Lane Closure  356159.86762  5.876918e+06               4/4/2022
#
#              Cell Coverage  UTM Zone
# 0                      NaN      11.0
# 1                      NaN      11.0
# 2                      NaN      11.0
# 3                      NaN      11.0
# 4                      NaN       NaN
# ..                     ...       ...
# 619                    NaN       NaN
# 620                    NaN       NaN
# 621                    NaN       NaN
# 622  No Cell Coverage Area      11.0
# 623  No Cell Coverage Area      11.0
#
# [624 rows x 14 columns]

# %%
weather_all = pd.DataFrame()

# for station_id in df_matched_weather_ids['Weather:StationID'].unique():
for folder_name in os.listdir(weather_path):
    if not folder_name.isnumeric():
        print(f'!! {folder_name} ignored.')
        continue
    station_id = int(folder_name)
    weather_joined_files = glob.glob(os.path.join(weather_path, f'{station_id}/*.csv'))
    weather_station = load_csv_to_df(weather_joined_files)

    weather_station.insert(loc=0, column='StationID', value=station_id)
    weather_station['Date/Time (LST)'] = pd.to_datetime(weather_station['Date/Time (LST)'])
    # df_weather_station['Date'] = df_weather_station['Date/Time (LST)'].dt.date
    weather_station.insert(loc=weather_station.columns.get_loc('Date/Time (LST)')+1, column='Date', value= weather_station['Date/Time (LST)'].dt.date)
    weather_station.insert(loc=weather_station.columns.get_loc('Time (LST)')+1, column='Hour', value= weather_station['Date/Time (LST)'].dt.hour)

    weather_all = pd.concat([weather_all, weather_station[['StationID', 'Longitude (x)', 'Latitude (y)', 'Date', 'Hour', 'Temp (°C)', 'Precip. Amount (mm)', 'Wind Spd (km/h)']]], axis=0)

weather_all.rename(columns = {'Temp (°C)':'Temp',
                             'Precip. Amount (mm)':'Precip',
                             'Wind Spd (km/h)':'WindSpd',
                             'Longitude (x)':'Long',
                             'Latitude (y)':'Lat'},
                  inplace=True)
weather_all.columns = ['Weather:' + str(col) for col in weather_all.columns]
weather_all = weather_all.drop_duplicates()
weather_all
# Out:
# !! daily 702 ignored.
# !! Recommended Assets Merged.csv ignored.
# !! SelectedWeatherStations_50KM.xlsx ignored.
# !! Station Inventory EN.csv ignored.
# !! WeatherInfo_Command_Lines_EN.txt ignored.
# !! WeatherStationsInfo.zip ignored.
#        Weather:StationID  Weather:Long  Weather:Lat Weather:Date  \
# 0                   1022       -120.80        50.11   2020-01-01
# 1                   1022       -120.80        50.11   2020-01-01
# 2                   1022       -120.80        50.11   2020-01-01
# 3                   1022       -120.80        50.11   2020-01-01
# 4                   1022       -120.80        50.11   2020-01-01
# ...                  ...           ...          ...          ...
# 26299                998       -121.02        50.47   2022-09-30
# 26300                998       -121.02        50.47   2022-09-30
# 26301                998       -121.02        50.47   2022-09-30
# 26302                998       -121.02        50.47   2022-09-30
# 26303                998       -121.02        50.47   2022-09-30
#
#        Weather:Hour  Weather:Temp  Weather:Precip  Weather:WindSpd
# 0                 0           NaN             NaN              NaN
# 1                 1           NaN             NaN              NaN
# 2                 2           NaN             NaN              NaN
# 3                 3           NaN             NaN              NaN
# 4                 4           NaN             NaN              NaN
# ...             ...           ...             ...              ...
# 26299            19           NaN             NaN              NaN
# 26300            20           NaN             NaN              NaN
# 26301            21           NaN             NaN              NaN
# 26302            22           NaN             NaN              NaN
# 26303            23           NaN             NaN              NaN
#
# [1052160 rows x 8 columns]

# %%
weather =  weather_all.dropna(subset=['Weather:Temp', 'Weather:Precip', 'Weather:WindSpd']).copy()
# weather =  weather_all.dropna(subset=['Weather:Temp']).copy().reset_index(drop=True)
# weather = weather.dropna(subset=['Weather:Temp', 'Weather:Precip', 'Weather:WindSpd'])
weather['Weather:Date'] = pd.to_datetime(weather['Weather:Date'])
weather
# Out:
#        Weather:StationID  Weather:Long  Weather:Lat Weather:Date  \
# 0                  10223       -118.03        52.93   2020-01-01
# 1                  10223       -118.03        52.93   2020-01-01
# 2                  10223       -118.03        52.93   2020-01-01
# 3                  10223       -118.03        52.93   2020-01-01
# 4                  10223       -118.03        52.93   2020-01-01
# ...                  ...           ...          ...          ...
# 23875               8214       -119.29        52.13   2022-06-21
# 23876               8214       -119.29        52.13   2022-06-21
# 23877               8214       -119.29        52.13   2022-06-21
# 23878               8214       -119.29        52.13   2022-06-21
# 23879               8214       -119.29        52.13   2022-06-21
#
#        Weather:Hour  Weather:Temp  Weather:Precip  Weather:WindSpd
# 0                 0          -2.0             0.2              4.0
# 1                 1          -2.1             0.2              4.0
# 2                 2          -2.1             0.3              5.0
# 3                 3          -2.3             0.0              6.0
# 4                 4          -2.3             0.4              4.0
# ...             ...           ...             ...              ...
# 23875            19          12.9             0.6              4.0
# 23876            20          12.5             0.4              3.0
# 23877            21          12.3             1.0              2.0
# 23878            22          11.9             0.7              4.0
# 23879            23          11.6             0.3              2.0
#
# [150018 rows x 8 columns]

# %%
travel_t_na = travel_t[travel_t[['Weather:Temp', 'Weather:Precip', 'Weather:WindSpd']].isna().any(axis=1)]
# travel_t.dropna(subset=['Weather:Temp', 'Weather:Precip', 'Weather:WindSpd'])
travel_t_na
# Out:
#          AssetNumber                                    AssetIdentifier  \
# 41177    98626596943  AP 3-B-17-A, AP 3-B-Hwy 5-3, AP 3-B-Hwy 5-4 • ...
# 41178    98626596943  AP 3-B-17-A, AP 3-B-Hwy 5-3, AP 3-B-Hwy 5-4 • ...
# 41179    98626596943  AP 3-B-17-A, AP 3-B-Hwy 5-3, AP 3-B-Hwy 5-4 • ...
# 41180    98626596943  AP 3-B-17-A, AP 3-B-Hwy 5-3, AP 3-B-Hwy 5-4 • ...
# 41181    98626596943  AP 3-B-17-A, AP 3-B-Hwy 5-3, AP 3-B-Hwy 5-4 • ...
# ...              ...                                                ...
# 1704013  55858030442  AP 6-A-Hwy 1 E-2 • NB • Macro Spiecapag JV • 1052
# 1704014  55858030442  AP 6-A-Hwy 1 E-2 • NB • Macro Spiecapag JV • 1052
# 1704015  55858030442  AP 6-A-Hwy 1 E-2 • NB • Macro Spiecapag JV • 1052
# 1704016  55858030442  AP 6-A-Hwy 1 E-2 • NB • Macro Spiecapag JV • 1052
# 1704017  55858030442  AP 6-A-Hwy 1 E-2 • NB • Macro Spiecapag JV • 1052
#
#                  CreatedDate  UnderConstructionTime  BaselineTime  DelayTime  \
# 41177    2021-05-14 21:00:11                   3.45          2.53       0.92
# 41178    2021-05-14 21:05:12                   2.85          2.53       0.32
# 41179    2021-05-14 21:10:12                   2.77          2.53       0.24
# 41180    2021-05-14 21:15:13                   2.78          2.53       0.25
# 41181    2021-05-14 21:17:15                   2.77          2.53       0.24
# ...                      ...                    ...           ...        ...
# 1704013  2021-04-15 18:15:10                   1.33          1.27       0.06
# 1704014  2021-04-15 18:20:10                   1.33          1.27       0.06
# 1704015  2021-04-15 18:25:11                   1.28          1.27       0.01
# 1704016  2021-04-15 18:30:09                   1.28          1.27       0.01
# 1704017  2021-04-15 18:35:11                   1.28          1.27       0.01
#
#         State  SegmentLength TravelDirect     Spread  ... Weather:Lat  \
# 41177      OK          3.337           SB  Spread 3B  ...       52.72
# 41178      OK          3.337           SB  Spread 3B  ...       52.72
# 41179      OK          3.337           SB  Spread 3B  ...       52.72
# 41180      OK          3.337           SB  Spread 3B  ...       52.72
# 41181      OK          3.337           SB  Spread 3B  ...       52.72
# ...       ...            ...          ...        ...  ...         ...
# 1704013    OK          2.160           NB  Spread 5B  ...       49.36
# 1704014    OK          2.160           NB  Spread 5B  ...       49.36
# 1704015    OK          2.160           NB  Spread 5B  ...       49.36
# 1704016    OK          2.160           NB  Spread 5B  ...       49.36
# 1704017    OK          2.160           NB  Spread 5B  ...       49.36
#
#         Weather:Temp Weather:Precip Weather:WindSpd  Traffic:SiteNo  \
# 41177            NaN            NaN             NaN        23-010NS
# 41178            NaN            NaN             NaN        23-010NS
# 41179            NaN            NaN             NaN        23-010NS
# 41180            NaN            NaN             NaN        23-010NS
# 41181            NaN            NaN             NaN        23-010NS
# ...              ...            ...             ...             ...
# 1704013          NaN            NaN             NaN        P-17-11E
# 1704014          NaN            NaN             NaN        P-17-11E
# 1704015          NaN            NaN             NaN        P-17-11E
# 1704016          NaN            NaN             NaN        P-17-11E
# 1704017          NaN            NaN             NaN        P-17-11E
#
#          Traffic:IsTemporary  Traffic:AADT  Traffic:BaseYear  \
# 41177                   True         126.0            2017.0
# 41178                   True         126.0            2017.0
# 41179                   True         126.0            2017.0
# 41180                   True         126.0            2017.0
# 41181                   True         126.0            2017.0
# ...                      ...           ...               ...
# 1704013                  NaN           NaN               NaN
# 1704014                  NaN           NaN               NaN
# 1704015                  NaN           NaN               NaN
# 1704016                  NaN           NaN               NaN
# 1704017                  NaN           NaN               NaN
#
#          Traffic:CalculatedAADT  MaxSpeed
# 41177                    131.04      90.0
# 41178                    131.04      90.0
# 41179                    131.04      90.0
# 41180                    131.04      90.0
# 41181                    131.04      90.0
# ...                         ...       ...
# 1704013                     NaN     100.0
# 1704014                     NaN     100.0
# 1704015                     NaN     100.0
# 1704016                     NaN     100.0
# 1704017                     NaN     100.0
#
# [944577 rows x 34 columns]

# %%
def find_nearest_ws(asset, wss):
    dists = []
    for ws in wss:
        # dists.append(np.linalg.norm(asset - ws, axis=1)[0])
        dists.append(np.linalg.norm(asset - ws))
    # print('dists', dists, '\n')
    return np.argmin(dists)


# def convert_coordinates(easting, northing, utm_zone):
def convert_coordinates(asset_info):
    print('\n\n', asset_info)
    easting = asset_info['Easting']
    northing = asset_info['Northing']
    utm_zone = asset_info['UTM Zone']

    if np.isnan(easting) or np.isnan(northing) or np.isnan(utm_zone):
        # print("!!! DANGER")
        # print(easting, northing)
        return np.nan

    if pd.isna(utm_zone):
        if easting > 600000:
            utm_zone = 10
        elif easting < 600000:
            utm_zone = 11
        else:
            # if np.isnan(easting) or np.isnan(northing) or np.isnan(utm_zone):
            #     print("!!! DANGER")
            # print(easting, northing)
            # print(f"utm_zone = {utm_zone} \n")
            return np.nan

    utm_zone = int(utm_zone)

    proj_lonlat_to_EN = pyproj.Proj(proj='utm', zone=utm_zone, ellps='WGS84')

    # ea , no = proj_lonlat_to_EN(lon, lat)
    lon, lat = proj_lonlat_to_EN(easting, northing, inverse=True)

    return [lon , lat]

# %%
assets['Longitude_Latitude'] = assets.apply(convert_coordinates, axis=1)
assets
# Out:
#  Asset Number                                62134790681
# Segment Name                              AP 3-B-12-A-1
# Segment Length                                    2.746
# Baseline                                           1.72
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    344630.96633
# Northing                                  5861839.09318
# Most Recent Activation                        2/25/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 0, dtype: object
#
#
#  Asset Number                                10897197432
# Segment Name                              AP 3-B-12-A-1
# Segment Length                                    2.746
# Baseline                                           1.73
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    344630.96633
# Northing                                  5861839.09318
# Most Recent Activation                        2/25/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 1, dtype: object
#
#
#  Asset Number                                12768050215
# Segment Name                              AP 3-B-13-A-1
# Segment Length                                     2.97
# Baseline                                           1.92
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    344922.86601
# Northing                                  5860906.07773
# Most Recent Activation                         4/2/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 2, dtype: object
#
#
#  Asset Number                                56678162306
# Segment Name                              AP 3-B-13-A-1
# Segment Length                                     2.97
# Baseline                                           1.92
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    344922.86601
# Northing                                  5860906.07773
# Most Recent Activation                         4/2/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 3, dtype: object
#
#
#  Asset Number                                86851077697
# Segment Name                              AP 3-B-13-A-3
# Segment Length                                     18.0
# Baseline                                            NaN
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    346092.86128
# Northing                                  5857159.23224
# Most Recent Activation                              NaN
# Cell Coverage                                       NaN
# UTM Zone                                            NaN
# Name: 4, dtype: object
#
#
#  Asset Number                                49837909751
# Segment Name                              AP 3-B-13-A-3
# Segment Length                                      1.0
# Baseline                                            1.0
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    346092.86128
# Northing                                  5857159.23224
# Most Recent Activation                              NaN
# Cell Coverage                                       NaN
# UTM Zone                                            NaN
# Name: 5, dtype: object
#
#
#  Asset Number                                71808680042
# Segment Name                                AP 3-B-17-A
# Segment Length                                    3.337
# Baseline                                            2.6
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    345859.59737
# Northing                                   5857858.1374
# Most Recent Activation                         5/3/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 6, dtype: object
#
#
#  Asset Number                                98626596943
# Segment Name                                AP 3-B-17-A
# Segment Length                                    3.337
# Baseline                                            2.7
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    345859.59737
# Northing                                   5857858.1374
# Most Recent Activation                         5/3/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 7, dtype: object
#
#
#  Asset Number                                86710465442
# Segment Name                              AP 3-B-22.1-A
# Segment Length                                     1.08
# Baseline                                           0.88
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    346840.91598
# Northing                                  5854642.58241
# Most Recent Activation                              NaN
# Cell Coverage                                       NaN
# UTM Zone                                            NaN
# Name: 8, dtype: object
#
#
#  Asset Number                                65827538011
# Segment Name                              AP 3-B-22.1-A
# Segment Length                                     1.08
# Baseline                                            0.0
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    346840.91598
# Northing                                  5854642.58241
# Most Recent Activation                              NaN
# Cell Coverage                                       NaN
# UTM Zone                                            NaN
# Name: 9, dtype: object
#
#
#  Asset Number                                86411712234
# Segment Name                                AP 3-B-22-B
# Segment Length                                     1.07
# Baseline                                           0.85
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    346961.99999
# Northing                                  5854217.00006
# Most Recent Activation                       11/23/2021
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 10, dtype: object
#
#
#  Asset Number                                19866794678
# Segment Name                                AP 3-B-22-B
# Segment Length                                     1.07
# Baseline                                           0.83
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    346961.99999
# Northing                                  5854217.00006
# Most Recent Activation                       11/23/2021
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 11, dtype: object
#
#
#  Asset Number                                87689561403
# Segment Name                              AP 3-B-23.1-A
# Segment Length                                    2.798
# Baseline                                           1.85
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    347515.94501
# Northing                                  5852426.69587
# Most Recent Activation                       11/10/2021
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 12, dtype: object
#
#
#  Asset Number                                96372842175
# Segment Name                              AP 3-B-23.1-A
# Segment Length                                    2.798
# Baseline                                           1.88
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    347515.94501
# Northing                                  5852426.69587
# Most Recent Activation                       11/10/2021
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 13, dtype: object
#
#
#  Asset Number                                        49831911074
# Segment Name                                      AP 3-B-29.1-B
# Segment Length                                             3.36
# Baseline                                                   2.13
# Direct of Travel                                             SB
# Spread                                                Spread 3B
# Traffic Impact                                             High
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                                      SLAT
# Easting                                            348002.44207
# Northing                                          5850748.73131
# Most Recent Activation                                 5/3/2022
# Cell Coverage                                               NaN
# UTM Zone                                                   11.0
# Name: 14, dtype: object
#
#
#  Asset Number                                        53257039399
# Segment Name                                      AP 3-B-29.1-B
# Segment Length                                            3.363
# Baseline                                                   2.15
# Direct of Travel                                             NB
# Spread                                                Spread 3B
# Traffic Impact                                             High
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                                      SLAT
# Easting                                            348002.44207
# Northing                                          5850748.73131
# Most Recent Activation                                 5/3/2022
# Cell Coverage                                               NaN
# UTM Zone                                                   11.0
# Name: 15, dtype: object
#
#
#  Asset Number                                87275350452
# Segment Name                                AP 3-B-33-A
# Segment Length                                     3.51
# Baseline                                           2.23
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                     347906.1023
# Northing                                   5849963.3321
# Most Recent Activation                        4/22/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 16, dtype: object
#
#
#  Asset Number                                29549024075
# Segment Name                                AP 3-B-33-A
# Segment Length                                     3.51
# Baseline                                           2.22
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                     347906.1023
# Northing                                   5849963.3321
# Most Recent Activation                        4/22/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 17, dtype: object
#
#
#  Asset Number                                50195678222
# Segment Name                                   AP 3-B-5
# Segment Length                                     5.23
# Baseline                                           3.15
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    340593.22711
# Northing                                  5867339.96436
# Most Recent Activation                        2/28/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 18, dtype: object
#
#
#  Asset Number                                96127319335
# Segment Name                                   AP 3-B-5
# Segment Length                                     5.23
# Baseline                                           3.13
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    340593.22711
# Northing                                  5867339.96436
# Most Recent Activation                        2/28/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 19, dtype: object
#
#
#  Asset Number                                43494072994
# Segment Name                                   AP 3-B-8
# Segment Length                                     4.62
# Baseline                                            2.0
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    342073.88073
# Northing                                  5865367.11555
# Most Recent Activation                        8/24/2021
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 20, dtype: object
#
#
#  Asset Number                                93064852668
# Segment Name                                   AP 3-B-8
# Segment Length                                     4.62
# Baseline                                            2.0
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    342073.88073
# Northing                                  5865367.11555
# Most Recent Activation                        8/24/2021
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 21, dtype: object
#
#
#  Asset Number                                14014037003
# Segment Name                             AP 3-B-Hwy 5-2
# Segment Length                                     4.46
# Baseline                                           2.73
# Direct of Travel                                     NB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    344044.65301
# Northing                                  5862736.09259
# Most Recent Activation                        4/29/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 22, dtype: object
#
#
#  Asset Number                                64277836054
# Segment Name                             AP 3-B-Hwy 5-2
# Segment Length                                     4.46
# Baseline                                           2.77
# Direct of Travel                                     SB
# Spread                                        Spread 3B
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    344044.65301
# Northing                                  5862736.09259
# Most Recent Activation                        4/29/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 23, dtype: object
#
#
#  Asset Number                                32619387794
# Segment Name                                AP 3-C-35-C
# Segment Length                                     3.33
# Baseline                                           2.05
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    347385.87228
# Northing                                  5848437.43811
# Most Recent Activation                        2/10/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 24, dtype: object
#
#
#  Asset Number                                40822621367
# Segment Name                                AP 3-C-35-C
# Segment Length                                     3.33
# Baseline                                            2.0
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    347385.87228
# Northing                                  5848437.43811
# Most Recent Activation                        2/10/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 25, dtype: object
#
#
#  Asset Number                                37709753226
# Segment Name                                AP 3-C-36-A
# Segment Length                                     2.75
# Baseline                                            1.7
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    347005.15391
# Northing                                  5845800.05376
# Most Recent Activation                         4/1/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 26, dtype: object
#
#
#  Asset Number                                32211388294
# Segment Name                                AP 3-C-36-A
# Segment Length                                     2.75
# Baseline                                           1.68
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    347005.15391
# Northing                                  5845800.05376
# Most Recent Activation                         4/1/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 27, dtype: object
#
#
#  Asset Number                                89235725358
# Segment Name                                AP 3-C-37-A
# Segment Length                                     2.76
# Baseline                                            1.7
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    346894.92716
# Northing                                  5844783.02996
# Most Recent Activation                         3/1/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 28, dtype: object
#
#
#  Asset Number                                64076632864
# Segment Name                                AP 3-C-37-A
# Segment Length                                     2.76
# Baseline                                           1.75
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    346894.92716
# Northing                                  5844783.02996
# Most Recent Activation                         3/1/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 29, dtype: object
#
#
#  Asset Number                                83775772469
# Segment Name                                AP 3-C-38-A
# Segment Length                                     2.64
# Baseline                                            0.0
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    347060.27674
# Northing                                  5843384.17846
# Most Recent Activation                              NaN
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 30, dtype: object
#
#
#  Asset Number                                69397841741
# Segment Name                                AP 3-C-38-A
# Segment Length                                     2.64
# Baseline                                            0.0
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    347060.27674
# Northing                                  5843384.17846
# Most Recent Activation                              NaN
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 31, dtype: object
#
#
#  Asset Number                                89198832075
# Segment Name                                AP 3-C-39-A
# Segment Length                                     3.66
# Baseline                                           2.18
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    347628.84903
# Northing                                  5841782.70122
# Most Recent Activation                         5/4/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 32, dtype: object
#
#
#  Asset Number                                52875362848
# Segment Name                                AP 3-C-39-A
# Segment Length                                     3.66
# Baseline                                           2.23
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    347628.84903
# Northing                                  5841782.70122
# Most Recent Activation                         5/4/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 33, dtype: object
#
#
#  Asset Number                                21550771877
# Segment Name                                AP 3-C-42-A
# Segment Length                                     3.59
# Baseline                                            2.0
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    349857.91078
# Northing                                  5838693.24925
# Most Recent Activation                         5/3/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 34, dtype: object
#
#
#  Asset Number                                59441524480
# Segment Name                                AP 3-C-42-A
# Segment Length                                     3.59
# Baseline                                            2.0
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    349857.91078
# Northing                                  5838693.24925
# Most Recent Activation                         5/3/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 35, dtype: object
#
#
#  Asset Number                                        88786298092
# Segment Name                                        AP 3-C-44-A
# Segment Length                                             4.08
# Baseline                                                   2.47
# Direct of Travel                                             NB
# Spread                                                Spread 3C
# Traffic Impact                                              Low
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                                      SLAT
# Easting                                            351237.31735
# Northing                                          5837113.33181
# Most Recent Activation                                 5/4/2022
# Cell Coverage                                               NaN
# UTM Zone                                                   11.0
# Name: 36, dtype: object
#
#
#  Asset Number                                        33388067973
# Segment Name                                        AP 3-C-44-A
# Segment Length                                             4.08
# Baseline                                                   2.53
# Direct of Travel                                             SB
# Spread                                                Spread 3C
# Traffic Impact                                              Low
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                                      SLAT
# Easting                                            351237.31735
# Northing                                          5837113.33181
# Most Recent Activation                                 5/4/2022
# Cell Coverage                                               NaN
# UTM Zone                                                   11.0
# Name: 37, dtype: object
#
#
#  Asset Number                                90064147260
# Segment Name                                AP 3-C-45-A
# Segment Length                                     2.75
# Baseline                                            1.0
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    351588.92393
# Northing                                  5836467.94887
# Most Recent Activation                              NaN
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 38, dtype: object
#
#
#  Asset Number                                36181764255
# Segment Name                                AP 3-C-45-A
# Segment Length                                      1.0
# Baseline                                            1.0
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    351588.92393
# Northing                                  5836467.94887
# Most Recent Activation                              NaN
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 39, dtype: object
#
#
#  Asset Number                                84220168833
# Segment Name                              AP 3-C-49.1-A
# Segment Length                                      3.3
# Baseline                                           2.13
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    355885.99965
# Northing                                  5831313.00012
# Most Recent Activation                         2/1/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 40, dtype: object
#
#
#  Asset Number                                50744787359
# Segment Name                              AP 3-C-49.1-A
# Segment Length                                      3.3
# Baseline                                           2.08
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    355885.99965
# Northing                                  5831313.00012
# Most Recent Activation                         2/1/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 41, dtype: object
#
#
#  Asset Number                                89842232512
# Segment Name                                AP 3-C-50-B
# Segment Length                                     3.03
# Baseline                                            0.0
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    356352.41961
# Northing                                  5830836.27742
# Most Recent Activation                              NaN
# Cell Coverage                                       NaN
# UTM Zone                                            NaN
# Name: 42, dtype: object
#
#
#  Asset Number                                25754934797
# Segment Name                             AP 3-C-50-B SB
# Segment Length                                     3.03
# Baseline                                            0.0
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    356352.41961
# Northing                                  5830836.27742
# Most Recent Activation                              NaN
# Cell Coverage                                       NaN
# UTM Zone                                            NaN
# Name: 43, dtype: object
#
#
#  Asset Number                                90902630967
# Segment Name                                AP 3-C-51-A
# Segment Length                                     2.67
# Baseline                                           1.67
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    357877.99998
# Northing                                  5828654.99996
# Most Recent Activation                         5/3/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 44, dtype: object
#
#
#  Asset Number                                75785193191
# Segment Name                                AP 3-C-51-A
# Segment Length                                     2.67
# Baseline                                            1.7
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    357877.99998
# Northing                                  5828654.99996
# Most Recent Activation                         5/3/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 45, dtype: object
#
#
#  Asset Number                                89649936309
# Segment Name                                AP 3-C-52-A
# Segment Length                                     3.56
# Baseline                                           2.35
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    356839.73342
# Northing                                  5830400.82553
# Most Recent Activation                        3/30/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 46, dtype: object
#
#
#  Asset Number                                30623181508
# Segment Name                                AP 3-C-52-A
# Segment Length                                     3.56
# Baseline                                           2.38
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    356839.73342
# Northing                                  5830400.82553
# Most Recent Activation                        3/30/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 47, dtype: object
#
#
#  Asset Number                                84288924497
# Segment Name                                AP 3-C-52-E
# Segment Length                                     2.66
# Baseline                                           1.68
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    357646.79699
# Northing                                  5826546.03209
# Most Recent Activation                         5/2/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 48, dtype: object
#
#
#  Asset Number                                84204357923
# Segment Name                                AP 3-C-52-E
# Segment Length                                     2.66
# Baseline                                           1.65
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    357646.79699
# Northing                                  5826546.03209
# Most Recent Activation                         5/2/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 49, dtype: object
#
#
#  Asset Number                                        22494493272
# Segment Name                                        AP 3-C-55-A
# Segment Length                                             4.21
# Baseline                                                   2.58
# Direct of Travel                                             NB
# Spread                                                Spread 3C
# Traffic Impact                                             High
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                                      SLAT
# Easting                                            356491.59848
# Northing                                          5822877.60519
# Most Recent Activation                                 5/3/2022
# Cell Coverage                             No Cell Coverage Area
# UTM Zone                                                   11.0
# Name: 50, dtype: object
#
#
#  Asset Number                                        23793412409
# Segment Name                                        AP 3-C-55-A
# Segment Length                                             4.21
# Baseline                                                   2.62
# Direct of Travel                                             SB
# Spread                                                Spread 3C
# Traffic Impact                                             High
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                                      SLAT
# Easting                                            356491.59848
# Northing                                          5822877.60519
# Most Recent Activation                                 5/3/2022
# Cell Coverage                             No Cell Coverage Area
# UTM Zone                                                   11.0
# Name: 51, dtype: object
#
#
#  Asset Number                                75139461327
# Segment Name                             AP 3-C-57-A NB
# Segment Length                                     3.53
# Baseline                                           2.25
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    356705.10781
# Northing                                  5821534.69252
# Most Recent Activation                        4/26/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 52, dtype: object
#
#
#  Asset Number                                68536760632
# Segment Name                             AP 3-C-57-A SB
# Segment Length                                     3.53
# Baseline                                           2.27
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    356705.10781
# Northing                                  5821534.69252
# Most Recent Activation                        4/26/2022
# Cell Coverage                                       NaN
# UTM Zone                                           11.0
# Name: 53, dtype: object
#
#
#  Asset Number                                91388951517
# Segment Name                                AP 3-C-58-A
# Segment Length                                     4.03
# Baseline                                           2.37
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    357033.42384
# Northing                                  5819702.28999
# Most Recent Activation                         5/2/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 54, dtype: object
#
#
#  Asset Number                                49588776280
# Segment Name                                AP 3-C-58-A
# Segment Length                                     4.03
# Baseline                                           2.37
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    357033.42384
# Northing                                  5819702.28999
# Most Recent Activation                         5/2/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 55, dtype: object
#
#
#  Asset Number                                40422297973
# Segment Name                                AP 3-C-58-B
# Segment Length                                     2.81
# Baseline                                            0.0
# Direct of Travel                                     SB
# Spread                                        Spread 3C
# Traffic Impact                                      Low
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    357069.90904
# Northing                                  5819908.51383
# Most Recent Activation                              NaN
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                            NaN
# Name: 56, dtype: object
#
#
#  Asset Number                                61630079816
# Segment Name                                AP 3-C-58-B
# Segment Length                                     2.81
# Baseline                                            1.6
# Direct of Travel                                     NB
# Spread                                        Spread 3C
# Traffic Impact                                      Low
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                              SLAT
# Easting                                    357069.90904
# Northing                                  5819908.51383
# Most Recent Activation                              NaN
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                            NaN
# Name: 57, dtype: object
#
#
#  Asset Number                                92666800686
# Segment Name                                AP 3-C-59-A
# Segment Length                                     2.79
# Baseline                                           1.67
# Direct of Travel                                     NB
# ...
# Traffic Impact                                              Low
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                            Brief Duration
# Easting                                            393089.79375
# Northing                                          5856789.18712
# Most Recent Activation                                4/22/2022
# Cell Coverage                             No Cell Coverage Area
# UTM Zone                                                   11.0
# Name: 609, dtype: object
#
#
#  Asset Number                                        24617595457
# Segment Name                                        MRPP-AP 9-B
# Segment Length                                             2.73
# Baseline                                                   1.65
# Direct of Travel                                             SB
# Spread                                             Reactivation
# Traffic Impact                                              Low
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                            Brief Duration
# Easting                                            392093.68735
# Northing                                          5857036.57104
# Most Recent Activation                                7/29/2021
# Cell Coverage                             No Cell Coverage Area
# UTM Zone                                                   11.0
# Name: 610, dtype: object
#
#
#  Asset Number                                        42450766624
# Segment Name                                        MRPP-AP 9-B
# Segment Length                                             2.73
# Baseline                                                   1.65
# Direct of Travel                                             NB
# Spread                                             Reactivation
# Traffic Impact                                              Low
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                            Brief Duration
# Easting                                            392093.68735
# Northing                                          5857036.57104
# Most Recent Activation                                7/29/2021
# Cell Coverage                             No Cell Coverage Area
# UTM Zone                                                   11.0
# Name: 611, dtype: object
#
#
#  Asset Number                                        87354339708
# Segment Name                                        MRPP-AP 9-C
# Segment Length                                             3.13
# Baseline                                                    1.9
# Direct of Travel                                             SB
# Spread                                             Reactivation
# Traffic Impact                                              Low
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                            Brief Duration
# Easting                                            392060.24724
# Northing                                          5857053.06934
# Most Recent Activation                                8/23/2021
# Cell Coverage                             No Cell Coverage Area
# UTM Zone                                                   11.0
# Name: 612, dtype: object
#
#
#  Asset Number                                        18661378775
# Segment Name                                        MRPP-AP 9-C
# Segment Length                                             3.13
# Baseline                                                    1.9
# Direct of Travel                                             NB
# Spread                                             Reactivation
# Traffic Impact                                              Low
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                            Brief Duration
# Easting                                            392060.24724
# Northing                                          5857053.06934
# Most Recent Activation                                8/23/2021
# Cell Coverage                             No Cell Coverage Area
# UTM Zone                                                   11.0
# Name: 613, dtype: object
#
#
#  Asset Number                                        33825903276
# Segment Name                                        MRPP-AP-4-B
# Segment Length                                            3.153
# Baseline                                                    1.9
# Direct of Travel                                             SB
# Spread                                             Reactivation
# Traffic Impact                                              Low
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                            Brief Duration
# Easting                                            398406.90117
# Northing                                          5858569.93915
# Most Recent Activation                               12/10/2021
# Cell Coverage                             No Cell Coverage Area
# UTM Zone                                                   11.0
# Name: 614, dtype: object
#
#
#  Asset Number                                        81232998481
# Segment Name                                        MRPP-AP-4-B
# Segment Length                                             3.15
# Baseline                                                   1.87
# Direct of Travel                                             NB
# Spread                                             Reactivation
# Traffic Impact                                              Low
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                            Brief Duration
# Easting                                            398406.90117
# Northing                                          5858569.93915
# Most Recent Activation                               12/10/2021
# Cell Coverage                             No Cell Coverage Area
# UTM Zone                                                   11.0
# Name: 615, dtype: object
#
#
#  Asset Number                                        20357136235
# Segment Name                                     MRPP-AP-4-C NB
# Segment Length                                             3.41
# Baseline                                                   2.17
# Direct of Travel                                             NB
# Spread                                             Reactivation
# Traffic Impact                                         Moderate
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                                      SLAT
# Easting                                            399808.26498
# Northing                                          5860158.91689
# Most Recent Activation                                 5/4/2022
# Cell Coverage                                               NaN
# UTM Zone                                                   11.0
# Name: 616, dtype: object
#
#
#  Asset Number                                        83698091251
# Segment Name                                     MRPP-AP-4-C SB
# Segment Length                                             3.41
# Baseline                                                   2.25
# Direct of Travel                                             SB
# Spread                                             Reactivation
# Traffic Impact                                         Moderate
# Road Type                 Two-Lane, Two-Way Roadways (>70 km/h)
# Traffic Control Setup                                      SLAT
# Easting                                            399808.26498
# Northing                                          5860158.91689
# Most Recent Activation                                 5/4/2022
# Cell Coverage                                               NaN
# UTM Zone                                                   11.0
# Name: 617, dtype: object
#
#
#  Asset Number                     36168627590
# Segment Name                         T3920.0
# Segment Length                          3.74
# Baseline                                 0.0
# Direct of Travel                          NB
# Spread                             Spread 5A
# Traffic Impact                          High
# Road Type                 Multi-Lane Divided
# Traffic Control Setup           Lane Closure
# Easting                          660846.9792
# Northing                       5552539.82808
# Most Recent Activation                   NaN
# Cell Coverage                            NaN
# UTM Zone                                 NaN
# Name: 618, dtype: object
#
#
#  Asset Number                     34684428742
# Segment Name                         T3920.0
# Segment Length                          4.84
# Baseline                                 0.0
# Direct of Travel                          SB
# Spread                             Spread 5A
# Traffic Impact                          High
# Road Type                 Multi-Lane Divided
# Traffic Control Setup           Lane Closure
# Easting                          660846.9792
# Northing                       5552539.82808
# Most Recent Activation                   NaN
# Cell Coverage                            NaN
# UTM Zone                                 NaN
# Name: 619, dtype: object
#
#
#  Asset Number                     69027783597
# Segment Name                         T4068.3
# Segment Length                          3.46
# Baseline                                 0.0
# Direct of Travel                          SB
# Spread                             Spread 5B
# Traffic Impact                          High
# Road Type                 Multi-Lane Divided
# Traffic Control Setup           Lane Closure
# Easting                                  NaN
# Northing                                 NaN
# Most Recent Activation                   NaN
# Cell Coverage                            NaN
# UTM Zone                                 NaN
# Name: 620, dtype: object
#
#
#  Asset Number                     92801985490
# Segment Name                         T4068.3
# Segment Length                          3.48
# Baseline                                 0.0
# Direct of Travel                          NB
# Spread                             Spread 5B
# Traffic Impact                          High
# Road Type                 Multi-Lane Divided
# Traffic Control Setup           Lane Closure
# Easting                                  NaN
# Northing                                 NaN
# Most Recent Activation                   NaN
# Cell Coverage                            NaN
# UTM Zone                                 NaN
# Name: 621, dtype: object
#
#
#  Asset Number                                16764775025
# Segment Name                                 TWS_460042
# Segment Length                                     3.69
# Baseline                                           2.58
# Direct of Travel                                     SB
# Spread                                     Reactivation
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                      Lane Closure
# Easting                                    356159.86762
# Northing                                   5876918.3056
# Most Recent Activation                         4/4/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 622, dtype: object
#
#
#  Asset Number                                86449733135
# Segment Name                                 TWS_460042
# Segment Length                                     3.69
# Baseline                                            2.6
# Direct of Travel                                     NB
# Spread                                     Reactivation
# Traffic Impact                                     High
# Road Type                 Multi-Lane Undivided Roadways
# Traffic Control Setup                      Lane Closure
# Easting                                    356159.86762
# Northing                                   5876918.3056
# Most Recent Activation                         4/4/2022
# Cell Coverage                     No Cell Coverage Area
# UTM Zone                                           11.0
# Name: 623, dtype: object
#      Asset Number   Segment Name  Segment Length  Baseline Direct of Travel  \
# 0     62134790681  AP 3-B-12-A-1           2.746      1.72               NB
# 1     10897197432  AP 3-B-12-A-1           2.746      1.73               SB
# 2     12768050215  AP 3-B-13-A-1           2.970      1.92               NB
# 3     56678162306  AP 3-B-13-A-1           2.970      1.92               SB
# 4     86851077697  AP 3-B-13-A-3          18.000       NaN               NB
# ..            ...            ...             ...       ...              ...
# 619   34684428742        T3920.0           4.840      0.00               SB
# 620   69027783597        T4068.3           3.460      0.00               SB
# 621   92801985490        T4068.3           3.480      0.00               NB
# 622   16764775025     TWS_460042           3.690      2.58               SB
# 623   86449733135     TWS_460042           3.690      2.60               NB
#
#            Spread Traffic Impact                      Road Type  \
# 0       Spread 3B           High  Multi-Lane Undivided Roadways
# 1       Spread 3B           High  Multi-Lane Undivided Roadways
# 2       Spread 3B           High  Multi-Lane Undivided Roadways
# 3       Spread 3B           High  Multi-Lane Undivided Roadways
# 4       Spread 3B           High  Multi-Lane Undivided Roadways
# ..            ...            ...                            ...
# 619     Spread 5A           High             Multi-Lane Divided
# 620     Spread 5B           High             Multi-Lane Divided
# 621     Spread 5B           High             Multi-Lane Divided
# 622  Reactivation           High  Multi-Lane Undivided Roadways
# 623  Reactivation           High  Multi-Lane Undivided Roadways
#
#     Traffic Control Setup       Easting      Northing Most Recent Activation  \
# 0                    SLAT  344630.96633  5.861839e+06              2/25/2022
# 1                    SLAT  344630.96633  5.861839e+06              2/25/2022
# 2                    SLAT  344922.86601  5.860906e+06               4/2/2022
# 3                    SLAT  344922.86601  5.860906e+06               4/2/2022
# 4                    SLAT  346092.86128  5.857159e+06                    NaN
# ..                    ...           ...           ...                    ...
# 619          Lane Closure  660846.97920  5.552540e+06                    NaN
# 620          Lane Closure           NaN           NaN                    NaN
# 621          Lane Closure           NaN           NaN                    NaN
# 622          Lane Closure  356159.86762  5.876918e+06               4/4/2022
# 623          Lane Closure  356159.86762  5.876918e+06               4/4/2022
#
#              Cell Coverage  UTM Zone  \
# 0                      NaN      11.0
# 1                      NaN      11.0
# 2                      NaN      11.0
# 3                      NaN      11.0
# 4                      NaN       NaN
# ..                     ...       ...
# 619                    NaN       NaN
# 620                    NaN       NaN
# 621                    NaN       NaN
# 622  No Cell Coverage Area      11.0
# 623  No Cell Coverage Area      11.0
#
#                             Longitude_Latitude
# 0    [-119.30910111899807, 52.883778480895074]
# 1    [-119.30910111899807, 52.883778480895074]
# 2    [-119.30432219789675, 52.875482049886536]
# 3    [-119.30432219789675, 52.875482049886536]
# 4                                          NaN
# ..                                         ...
# 619                                        NaN
# 620                                        NaN
# 621                                        NaN
# 622   [-119.14458716604344, 53.02244478139078]
# 623   [-119.14458716604344, 53.02244478139078]
#
# [624 rows x 15 columns]

# %%
# type(asset_info[['Easting', 'Northing']].values)
counter = 0
i = 0
for idx in travel_t_na.index:
    if i % 50000 == 0:
        print(f'{i / len(travel_t_na) * 100}% checked!!')
    obs = travel_t.loc[idx]

    if np.isnan(obs['Weather:Temp']) or np.isnan(obs['Weather:Precip']) or np.isnan(obs['Weather:WindSpd']):
        # print('idx =', idx)
        # print('BEFORE', obs[['Weather:Temp', 'Weather:Precip', 'Weather:WindSpd']])

        weather_time_matched = weather[
            (obs['CreatedDate:Date'] == weather['Weather:Date']) &
            (obs['CreatedDate:Hour'] == weather['Weather:Hour'])]

        asset_info = assets[obs['AssetNumber'] == assets['Asset Number']]

        weather_coordinates = weather_time_matched[['Weather:Lat', 'Weather:Long']]

        nearest_idx = find_nearest_ws(asset_info['Longitude_Latitude'].values[0], weather_time_matched[['Weather:Long', 'Weather:Lat']].values)
        # print(nearest_idx)
        nearset_ws = weather_time_matched.iloc[nearest_idx]


        travel_t.loc[idx, 'Weather:Temp'] = nearset_ws['Weather:Temp']
        travel_t.loc[idx, 'Weather:Precip'] = nearset_ws['Weather:Precip']
        travel_t.loc[idx, 'Weather:WindSpd'] = nearset_ws['Weather:WindSpd']

        # print('\n\nAFTER', travel_t.loc[idx][['Weather:Temp', 'Weather:Precip', 'Weather:WindSpd']])

        counter += 1
    i += 1
counter
# Out:
# 0.0% checked!!
# 5.293374706350038% checked!!
# 10.586749412700076% checked!!
# 15.880124119050116% checked!!
# 21.173498825400152% checked!!
# 26.46687353175019% checked!!
# 31.760248238100232% checked!!
# 37.05362294445027% checked!!
# 42.346997650800304% checked!!
# 47.64037235715035% checked!!
# 52.93374706350038% checked!!
# 58.22712176985042% checked!!
# 63.520496476200464% checked!!
# 68.8138711825505% checked!!
# 74.10724588890054% checked!!
# 79.40062059525057% checked!!
# 84.69399530160061% checked!!
# 89.98737000795064% checked!!
# 95.2807447143007% checked!!
# 421290

# %%
travel_t.isna().sum()
# Out:
# AssetNumber                     0
# AssetIdentifier                 0
# CreatedDate                     0
# UnderConstructionTime           0
# BaselineTime                   22
# DelayTime                      22
# State                          85
# SegmentLength                   0
# TravelDirect                    0
# Spread                          0
# TrafficImpact                   0
# RoadType                        0
# TrafficControlSetup             0
# CreatedDate:Date                0
# CreatedDate:Weekday             0
# CreatedDate:DayOfYear           0
# CreatedDate:Year                0
# CreatedDate:Month               0
# CreatedDate:Day                 0
# CreatedDate:Hour                0
# CreatedDate:MinuteInDay         0
# CreatedDate:Season              0
# Weather:StationID               0
# Weather:Long                    0
# Weather:Lat                     0
# Weather:Temp                    0
# Weather:Precip                  0
# Weather:WindSpd                 0
# Traffic:SiteNo                  0
# Traffic:IsTemporary        326167
# Traffic:AADT               326167
# Traffic:BaseYear           326167
# Traffic:CalculatedAADT     326167
# MaxSpeed                   347852
# dtype: int64

# %%
travel_t.to_csv(os.path.join(input_root_path, 'TravelTime_HaveCellCoverage_WeatherFillNaN.csv'))

# %%
# obs = travel_t_na.loc[1704012]
#
# weather_time_matched = weather[
#     (obs['CreatedDate:Date'] == weather['Weather:Date']) &
#     (obs['CreatedDate:Hour'] == weather['Weather:Hour'])]
# weather_time_matched
#
# asset_info = assets[obs['AssetNumber'] == assets['Asset Number']]
# asset_coordinate = asset_info[['Easting', 'Northing']]
#
# # asset_coordinate
# # weather_time_matched[['Weather:Long', 'Weather:Lat']]
#
# nearest_idx = find_nearest_ws(asset_coordinate.values, weather_time_matched[['Weather:Long', 'Weather:Lat']].values)
# print(nearest_idx)
# weather_time_matched.iloc[nearest_idx]
# # obs['AssetNumber']
